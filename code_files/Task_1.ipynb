# %% [markdown]
# ### Assignment Task: Decision Tree Implementation
#
# You are required to **complete the decision tree implementation in `tree/base.py`**.
# The code must follow these conditions:
#
# 1. The code should be written in **Python** and **not use existing libraries** other than those shared in class or already imported in the code.
#
# 2. Your decision tree should handle the following four cases:
#    - **Case i:** Discrete features, Discrete output
#    - **Case ii:** Discrete features, Real output
#    - **Case iii:** Real features, Discrete output
#    - **Case iv:** Real features, Real output
#
# 3. **Inputs:**
#    - Your model should accept real inputs only.
#    - For discrete inputs, you may convert the attributes into one-hot encoded vectors.
#
# 4. **Splitting Criteria:**
#    - For **discrete output**: Use Information Gain with Entropy or Gini Index.
#    - For **real output**: Use Information Gain with Mean Squared Error (MSE).
#
# 5. **Additional Requirement:**
#    - Your code should be able to plot/display the decision tree.
#
# **Marks:** 2.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

sys.path.append(os.path.abspath("../es335-25-fall-assignment-1"))

from tree.base import DecisionTree
from tree.base import DecisionTree
from tree.utils import *
from metrics import *
from IPython.display import display
np.random.seed(42)

# %% [markdown]
# Discrete Input Discrete Output

# %%
np.random.seed(42)
N = 30
P = 5
X = pd.DataFrame({i: pd.Series(np.random.randint(P, size=N), dtype="category") for i in range(5)})
y = pd.Series(np.random.randint(P, size=N), dtype="category")

tree = DecisionTree("DD", max_depth=5, save_plot=True, plot_name="my_tree")
tree.fit(X, y)
dot = tree.plot()

display(dot)
y_hat = tree.predict(X)
print("Accuracy: ", accuracy(y_hat, y))

for cls in y.unique():
    print("Precision: ", precision(y_hat, y, cls))
    print("Recall: ", recall(y_hat, y, cls))
# Out:
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0

# %% [markdown]
# Discrete Input Real Output

# %%
np.random.seed(42)
N = 30
P = 5
X = pd.DataFrame({i: pd.Series(np.random.randint(P, size=N), dtype="category") for i in range(5)})
y = pd.Series(np.random.randn(N))

tree = DecisionTree("DR", max_depth=5, save_plot=True, plot_name="my_tree")
tree.fit(X, y)
dot = tree.plot()

display(dot)
y_hat = tree.predict(X)
print("RMSE: ", rmse(y_hat, y))
print("MAE: ", mae(y_hat, y))
# Out:
# RMSE:  0.0
# MAE:  0.0

# %% [markdown]
# Real Input Discrete Output

# %%
np.random.seed(42)
N = 30
P = 5
X = pd.DataFrame(np.random.randn(N, P))
y = pd.Series(np.random.randint(P, size=N), dtype="category")

tree = DecisionTree("RD", max_depth=5, save_plot=True, plot_name="my_tree")
tree.fit(X, y)
dot = tree.plot()
display(dot)

y_hat = tree.predict(X)

print("Accuracy: ", accuracy(y_hat, y))
for cls in y.unique():
    print("Precision: ", precision(y_hat, y, cls))
    print("Recall: ", recall(y_hat, y, cls))
# Out:
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0
# Precision:  1.0
# Recall:  1.0

# %% [markdown]
# Real Input Real Output

# %%
np.random.seed(42)
N = 30
P = 5
X = pd.DataFrame(np.random.randn(N, P))
y = pd.Series(np.random.randn(N))

tree = DecisionTree("RR", max_depth=5, save_plot=True, plot_name="my_tree")
tree.fit(X, y)
dot = tree.plot()
display(dot)
y_hat = tree.predict(X)

print("RMSE: ", rmse(y_hat, y))
print("MAE: ", mae(y_hat, y))
# Out:
# RMSE:  0.3601329774475513
# MAE:  0.24067253750418457
